# %%
# !git clone https://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@github.com/mruniverse8/hw3_nv.git
# Out:
# Cloning into 'hw3_nv'...
# remote: Enumerating objects: 369, done.
# remote: Counting objects: 100% (369/369), done.
# remote: Compressing objects: 100% (243/243), done.
# remote: Total 369 (delta 156), reused 280 (delta 100), pack-reused 0 (from 0)
# Receiving objects: 100% (369/369), 264.82 KiB | 3.35 MiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
import os

# %%
os.chdir('hw3_nv')

# %%
os.environ['COMET_API_KEY'] = 'zU3p4a1OnqcOCvHi2gJAXdem5'
# !ls
# Out:
# CITATION.cff  inference.py  LICENSE  README.md	requirements.txt  src  train.py

# %%
# !git pull origin
# !git checkout hifigan
# Out:
# Already up to date.
# Branch 'hifigan' set up to track remote branch 'hifigan' from 'origin'.
# Switched to a new branch 'hifigan'

# %%
# !pip install -r requirements2.txt
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 40.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=9a45d184002527a056d63ae8926f99e8bfd2bf1d5eaed8ee7981d93c6e37f09f
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.1
#     Uninstalling pyarrow-19.0.1:
#       Successfully uninstalled pyarrow-19.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# ...

# %%
# !wget -P "./data/datasets/ljspeech" "https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2" && tar -xjf "./data/datasets/ljspeech/LJSpeech-1.1.tar.bz2" -C "./data/datasets/ljspeech"
# Out:
# --2025-12-10 13:08:56--  https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# Resolving data.keithito.com (data.keithito.com)... 185.93.1.243, 2400:52e0:1a00::1348:1
# Connecting to data.keithito.com (data.keithito.com)|185.93.1.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2748572632 (2.6G) [text/plain]
# Saving to: ‘./data/datasets/ljspeech/LJSpeech-1.1.tar.bz2’
#
# LJSpeech-1.1.tar.bz 100%[===================>]   2.56G   307MB/s    in 9.3s
#
# 2025-12-10 13:09:05 (282 MB/s) - ‘./data/datasets/ljspeech/LJSpeech-1.1.tar.bz2’ saved [2748572632/2748572632]

# %%
# !git checkout hifipar2
# Out:
# Branch 'hifipar2' set up to track remote branch 'hifipar2' from 'origin'.
# Switched to a new branch 'hifipar2'

# %%
# !python download_weights.py "https://drive.usercontent.google.com/download?id=1ADnFHn2ERInIpEyBAJmlNGoVUmNWRzVu&export=download&authuser=0&confirm=t&uuid=ce37fe06-778b-484d-834a-e48c49fe4957&at=ALWLOp4bZ3Y8FHjm3b0cuTraQTlr:1765372100688" -o "."
# Out:
# Downloaded and extracted ZIP file to . successfully.

# %%
# !ls
# Out:
# data		     LICENSE		requirements.txt  src
# download_weights.py  README.md		run.sh		  train.py
# inference.py	     requirements2.txt	saved_more

# %%
# !HYDRA_FULL_ERROR=1 python3 train.py -cn=1batch_overfit dataloader.batch_size=6 trainer.resume_from="checkpoint-epoch4.pth" trainer.epoch_len=2200
# Out:
# Resuming training from run kim9mo50jmwj0rfkwrnnlm9lw30wf4jk...
# Logging git commit and patch...
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ronaldofj83/pytorch-template-asr-example/kim9mo50jmwj0rfkwrnnlm9lw30wf4jk
#
# Multi-GPU training enabled on devices: [0, 1]
# Models wrapped with DataParallel on GPUs: [0, 1]
# DataParallel(
#   (module): HIFIGAN(
#     (pre_conv): Conv1d(80, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#     (res_block): ModuleList(
#       (0): ResBlock(
#         (lrel): LeakyReLU(negative_slope=0.1)
#         (conv1): ConvTranspose1d(128, 64, kernel_size=(16,), stride=(8,))
#         (mrf_blocks): ModuleList(
#           (0): MRFBlock(
#             (lst_block): ModuleList(
#               (0-1): 2 x Sequential(
#                 (0): LeakyReLU(negative_slope=0.1)
# ...

# %%
# !ls /kaggle/working/hw3_nv/saved_more/testing/ -la
# Out:
# total 711452
# drwxr-xr-x 2 root root      4096 Dec 10 00:42  .
# drwxr-xr-x 3 root root      4096 Dec 10 00:41  ..
# -rw-r--r-- 1 root root 424084896 Dec 10 00:42 'checkpoint-epoch1(1).pth'
# -rw-r--r-- 1 root root 304322127 Dec 10 00:42  checkpoint-epoch2.pth
# -rw-r--r-- 1 root root      2658 Dec 10 00:42  config.yaml
# -rw-r--r-- 1 root root        41 Dec 10 00:42  git_commit.txt
# -rw-r--r-- 1 root root      1174 Dec 10 00:42  git_diff.patch
# -rw-r--r-- 1 root root     94090 Dec 10 00:42  info.log
